# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data_file = "global-fossil-fuel-consumption.xlsx"

#Total
CO2_file = pd.read_excel(data_file,header=0,sheet_name="global-fossil-fuel-consumption")
CO2_Fuel = CO2_file["Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)"]
CO2_file.columns
CO2_file.head()

#Coal
#CO2_Fuel_Coal = pd.read_excel(data_file,header=1,sheet_name="CO2 FC - Coal")

#Oil
#CO2_Fuel_Oil = pd.read_excel(data_file,header=3,sheet_name="CO2 FC - Oil")

#Gas
#CO2_Fuel_Gas = pd.read_excel(data_file,header=3,sheet_name="CO2 FC - Gas")
# Out:
#   Entity      Code  Year  Coal (terawatt-hours)  Crude oil (terawatt-hours)  \
# 0  World  OWID_WRL  1850              569.44490                     0.00000
# 1  World  OWID_WRL  1860             1061.11196                     0.00000
# 2  World  OWID_WRL  1870             1641.66798                     5.55556
# 3  World  OWID_WRL  1880             2541.66870                    33.33336
# 4  World  OWID_WRL  1890             3855.55864                    88.88896
#
#    Natural gas (terawatt-hours)    Population           GDP  \
# 0                       0.00000  1.270591e+09           NaN
# 1                       0.00000  1.327610e+09           NaN
# 2                       0.00000  1.326907e+09  1.923917e+12
# 3                       0.00000  1.405146e+09           NaN
# 4                      33.33336  1.522735e+09           NaN
#
#    Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)
# 0                                            197.856
# 1                                            333.424
# 2                                            538.608
# 3                                            864.704
# 4                                           1304.384

# %%
#Total Fossil Fuel CO2 emissions
CO2_Fuel_Total = CO2_file["Coal (terawatt-hours)"] + CO2_file["Crude oil (terawatt-hours)"] + CO2_file["Natural gas (terawatt-hours)"]

#CO2 emissions from Coal
CO2_Fuel_Coal = CO2_file["Coal (terawatt-hours)"]

#CO2 emissions from Oil
CO2_Fuel_Oil = CO2_file["Crude oil (terawatt-hours)"]

#CO2 emissions from Gas
CO2_Fuel_Gas = CO2_file["Natural gas (terawatt-hours)"]

# %%
#Total
x_axis = CO2_file["Year"].tolist()
y_axis_Total = CO2_Fuel_Total.tolist()
plt.plot(x_axis,y_axis_Total,color='k',label="Total")

#Coal
y_axis_Coal = CO2_Fuel_Coal = CO2_file["Coal (terawatt-hours)"].tolist()
plt.plot(x_axis,y_axis_Coal,color='b',label="Coal",linestyle="--")

#Oil
y_axis_Oil = CO2_Fuel_Oil = CO2_file["Crude oil (terawatt-hours)"].tolist()
plt.plot(x_axis,y_axis_Oil,color='r',label="Oil",linestyle="--")

#Gas
y_axis_Gas = CO2_Fuel_Gas = CO2_file["Natural gas (terawatt-hours)"].tolist()
plt.plot(x_axis,y_axis_Gas,color='g',label="Gas",linestyle="--")

#print(y_axis_Total)
#plt.fill_between(32294.21268)

#Labels
plt.title("Global Consumption of CO2 from Fossil Fuels")
plt.xlabel("Year")
plt.ylabel("CO2 emissions \n(terawatt-hours)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.3569236212055">

# %%
#Percent difference of coal emission per year
#Total
total_list = CO2_Fuel_Final_df["Total Global CO2 emissions(million tonnes)"].tolist()
x_axis_diff = x_axis[1:]
y_axis_diff_Total = [(y - x)/x*100 for x,y in zip(total_list,total_list[1:])]
print(max(y_axis_diff_Total))

#max percent
max_perc = max(y_axis_diff_Total)
max_index = y_axis_diff_Total.index(max_perc)
max_year = x_axis_diff[max_index]
print(max_year)

plt.plot(x_axis_diff,y_axis_diff_Total,'-o',color='k',alpha=0.7,markersize=4)
plt.title("Yearly CO2 Emissions Percent Differences")
plt.ylabel("Percent Difference (%)")
plt.xlabel("Year")

plt.annotate("Max",xy=(max_year,max_perc),xytext=(max_year-11,max_perc-0.1),arrowprops=dict(facecolor='black',shrink=0.05))
plt.show()
# Out:
# 5.932162486590599
# 2010
